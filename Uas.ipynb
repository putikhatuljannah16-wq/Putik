# %% [markdown]
# <a href="https://colab.research.google.com/github/putikhatuljannah16-wq/Putik/blob/main/Uas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Data tetap
v = 5          # kecepatan konstan (m/s)
t_total = 10   # detik

waktu = []
posisi = []

s = 0  # posisi awal

for t in range(t_total + 1):
    waktu.append(t)
    posisi.append(s)

    # If: peringatan jika posisi lewat 30 m
    if s > 30:
        print("Posisi melebihi 30 meter pada t =", t, "detik")

    s = s + v  # GLB: s = s + v * Δt (Δt = 1 detik)

plt.plot(waktu, posisi)
plt.title("Gerak Lurus Beraturan (GLB)")
plt.xlabel("Waktu (detik)")
plt.ylabel("Posisi (meter)")
plt.grid(True)
plt.show()
# Out:
# Posisi melebihi 30 meter pada t = 7 detik
# Posisi melebihi 30 meter pada t = 8 detik
# Posisi melebihi 30 meter pada t = 9 detik
# Posisi melebihi 30 meter pada t = 10 detik
