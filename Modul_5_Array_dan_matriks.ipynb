# %% [markdown]
# <a href="https://colab.research.google.com/github/putikhatuljannah16-wq/Putik/blob/main/Modul_5_Array_dan_matriks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def input_matriks(baris, kolom, nama):
    print(f"\nMasukkan elemen matriks {nama} ({baris}x{kolom}):")
    matriks = []
    for i in range(baris):
        row = []
        for j in range(kolom):
            while True:
                try:
                    val = float(input(f"Elemen [{i+1},{j+1}]: "))
                    row.append(val)
                    break
                except ValueError:
                    print("Input harus angka!")
        matriks.append(row)
    return matriks

def print_matriks(matriks):
    for row in matriks:
        print("\t".join(f"{elemen:.2f}" for elemen in row))

def penjumlahan_matriks(A, B):
    baris = len(A)
    kolom = len(A[0])
    C = []
    for i in range(baris):
        row = []
        for j in range(kolom):
            row.append(A[i][j] + B[i][j])
        C.append(row)
    return C

def perkalian_matriks(A, B):
    m = len(A)
    p = len(A[0])
    n = len(B[0])
    C = []

    for i in range(m):
        row = []
        for j in range(n):
            total = 0
            for k in range(p):
                total += A[i][k] * B[k][j]
            row.append(total)
        C.append(row)
    return C

def transpose_matriks(A):
    baris_A = len(A)
    kolom_A = len(A[0])
    T = []

    for j in range(kolom_A):
        new_row = []
        for i in range(baris_A):
            new_row.append(A[i][j])
        T.append(new_row)
    return T


def main_menu(m_A, p_A, m_B, n_B):

    A = input_matriks(m_A, p_A, "A")
    B = input_matriks(m_B, n_B, "B")

    while True:
        print("\n" + "="*40)
        print(f"Pilihan Operasi untuk Matriks A ({m_A}x{p_A}) dan B ({m_B}x{n_B})")
        print("1. Penjumlahan dua matriks (A + B)")
        print("2. Perkalian dua matriks (A x B)")
        print("3. Transpose matriks (Matriks A)")
        print("4. Keluar")
        print("="*40)

        pilihan = input("Masukkan pilihan (1-4): ")

        try:
            pilihan = int(pilihan)
        except ValueError:
            print("Pilihan tidak valid. Masukkan angka 1-4.")
            continue

        if pilihan == 1:
            if m_A == m_B and p_A == n_B:
                C_jumlah = penjumlahan_matriks(A, B)
                print("\n--- Hasil Penjumlahan Matriks A + B ---")
                print_matriks(C_jumlah)
            else:
                print("\n--- Penjumlahan Gagal ---")
                print("Penjumlahan matriks hanya bisa dilakukan jika ukuran kedua matriks SAMA.")
                print(f"Ukuran A: {m_A}x{p_A}, Ukuran B: {m_B}x{n_B}")

        elif pilihan == 2:
            if p_A == m_B:
                C_kali = perkalian_matriks(A, B)
                print("\n--- Hasil Perkalian Matriks A x B ---")
                print_matriks(C_kali)
            else:
                print("\n--- Perkalian Gagal ---")
                print("Perkalian matriks hanya bisa dilakukan jika jumlah kolom matriks pertama (A) sama dengan jumlah baris matriks kedua (B).")
                print(f"Ukuran A: {m_A}x{p_A}, Ukuran B: {m_B}x{n_B}")

        elif pilihan == 3:
            A_transpose = transpose_matriks(A)
            print("\n--- Hasil Transpose Matriks A ---")
            print_matriks(A_transpose)

        elif pilihan == 4:
            print("\nTerima kasih! Keluar dari program.")
            break

        else:
            print("Pilihan tidak ada. Silakan pilih antara 1 hingga 4.")

def jalankan_kasus():

    kasus_data = {
        "Kasus 1": {"A": (2, 2), "B": (2, 2)},
        "Kasus 2": {"A": (2, 3), "B": (3, 2)},
        "Kasus 3": {"A": (3, 3), "B": (3, 3)},
        "Kasus 4": {"A": (3, 2), "B": (3, 2)}
    }

    print("PROGRAM OPERASI DASAR MATRIKS (Penjumlahan, Perkalian, Transpose)")

    while True:
        print("\nSilakan pilih Kasus yang ingin dijalankan:")
        for i, nama_kasus in enumerate(kasus_data.keys(), 1):
            data = kasus_data[nama_kasus]
            print(f"{i}. {nama_kasus}: Matriks A ({data['A'][0]}x{data['A'][1]}), Matriks B ({data['B'][0]}x{data['B'][1]})")
        print("5. Keluar Program Utama")

        pilihan_kasus = input("Masukkan nomor Kasus (1-5): ")

        if pilihan_kasus == '5':
            print("Keluar dari program utama.")
            break

        try:
            pilihan_int = int(pilihan_kasus)
            if 1 <= pilihan_int <= 4:
                nama_kasus = list(kasus_data.keys())[pilihan_int - 1]
                data = kasus_data[nama_kasus]

                print(f"\n======== {nama_kasus} Dijalankan ========")
                print(f"Ukuran Matriks: A({data['A'][0]}x{data['A'][1]}) dan B({data['B'][0]}x{data['B'][1]})")

                main_menu(data['A'][0], data['A'][1], data['B'][0], data['B'][1])

            else:
                print("Pilihan kasus tidak valid.")
        except ValueError:
            print("Input harus berupa angka.")


if __name__ == "__main__":
    jalankan_kasus()
# Out:
# PROGRAM OPERASI DASAR MATRIKS (Penjumlahan, Perkalian, Transpose)
#
# Silakan pilih Kasus yang ingin dijalankan:
# 1. Kasus 1: Matriks A (2x2), Matriks B (2x2)
# 2. Kasus 2: Matriks A (2x3), Matriks B (3x2)
# 3. Kasus 3: Matriks A (3x3), Matriks B (3x3)
# 4. Kasus 4: Matriks A (3x2), Matriks B (3x2)
# 5. Keluar Program Utama
# Masukkan nomor Kasus (1-5): 1
#
# ======== Kasus 1 Dijalankan ========
# Ukuran Matriks: A(2x2) dan B(2x2)
#
# Masukkan elemen matriks A (2x2):
# Elemen [1,1]: 1
# Elemen [1,2]: 2
# Elemen [2,1]: 3
# Elemen [2,2]: 4
#
# Masukkan elemen matriks B (2x2):
# Elemen [1,1]: 5
# Elemen [1,2]: 6
# Elemen [2,1]: 7
# Elemen [2,2]: 8
#
# ========================================
# Pilihan Operasi untuk Matriks A (2x2) dan B (2x2)
# 1. Penjumlahan dua matriks (A + B)
# 2. Perkalian dua matriks (A x B)
# 3. Transpose matriks (Matriks A)
# 4. Keluar
# ========================================
# Masukkan pilihan (1-4): 1
#
# --- Hasil Penjumlahan Matriks A + B ---
# 6.00	8.00
# 10.00	12.00
#
# ========================================
# Pilihan Operasi untuk Matriks A (2x2) dan B (2x2)
# 1. Penjumlahan dua matriks (A + B)
# 2. Perkalian dua matriks (A x B)
# 3. Transpose matriks (Matriks A)
# 4. Keluar
# ========================================
# Masukkan pilihan (1-4): 2
#
# --- Hasil Perkalian Matriks A x B ---
# 19.00	22.00
# 43.00	50.00
#
# ========================================
# Pilihan Operasi untuk Matriks A (2x2) dan B (2x2)
# 1. Penjumlahan dua matriks (A + B)
# 2. Perkalian dua matriks (A x B)
# 3. Transpose matriks (Matriks A)
# 4. Keluar
# ========================================
# Masukkan pilihan (1-4): 3
#
# --- Hasil Transpose Matriks A ---
# 1.00	3.00
# 2.00	4.00
#
# ========================================
# Pilihan Operasi untuk Matriks A (2x2) dan B (2x2)
# 1. Penjumlahan dua matriks (A + B)
# 2. Perkalian dua matriks (A x B)
# 3. Transpose matriks (Matriks A)
# 4. Keluar
# ========================================
# Masukkan pilihan (1-4): 4
#
# Terima kasih! Keluar dari program.
#
# Silakan pilih Kasus yang ingin dijalankan:
# 1. Kasus 1: Matriks A (2x2), Matriks B (2x2)
# 2. Kasus 2: Matriks A (2x3), Matriks B (3x2)
# 3. Kasus 3: Matriks A (3x3), Matriks B (3x3)
# 4. Kasus 4: Matriks A (3x2), Matriks B (3x2)
# 5. Keluar Program Utama
# Masukkan nomor Kasus (1-5): 2
#
# ======== Kasus 2 Dijalankan ========
# Ukuran Matriks: A(2x3) dan B(3x2)
#
# Masukkan elemen matriks A (2x3):
# Elemen [1,1]: 1
# Elemen [1,2]: 2
# Elemen [1,3]: 3
# Elemen [2,1]: 4
# Elemen [2,2]: 5
# Elemen [2,3]: 6
#
# Masukkan elemen matriks B (3x2):
# Elemen [1,1]: 7
# Elemen [1,2]: 8
# Elemen [2,1]: 9
# Elemen [2,2]: 10
# Elemen [3,1]: 11
# Elemen [3,2]: 12
#
# ========================================
# Pilihan Operasi untuk Matriks A (2x3) dan B (3x2)
# 1. Penjumlahan dua matriks (A + B)
# 2. Perkalian dua matriks (A x B)
# 3. Transpose matriks (Matriks A)
# 4. Keluar
# ========================================
# Masukkan pilihan (1-4): 1
#
# --- Penjumlahan Gagal ---
# Penjumlahan matriks hanya bisa dilakukan jika ukuran kedua matriks SAMA.
# Ukuran A: 2x3, Ukuran B: 3x2
#
# ========================================
# Pilihan Operasi untuk Matriks A (2x3) dan B (3x2)
# 1. Penjumlahan dua matriks (A + B)
# 2. Perkalian dua matriks (A x B)
# 3. Transpose matriks (Matriks A)
# 4. Keluar
# ========================================
# Masukkan pilihan (1-4): 2
#
# --- Hasil Perkalian Matriks A x B ---
# 58.00	64.00
# 139.00	154.00
#
# ========================================
# Pilihan Operasi untuk Matriks A (2x3) dan B (3x2)
# 1. Penjumlahan dua matriks (A + B)
# 2. Perkalian dua matriks (A x B)
# 3. Transpose matriks (Matriks A)
# 4. Keluar
# ========================================
# Masukkan pilihan (1-4): 3
#
# --- Hasil Transpose Matriks A ---
# 1.00	4.00
# 2.00	5.00
# 3.00	6.00
#
# ========================================
# Pilihan Operasi untuk Matriks A (2x3) dan B (3x2)
# 1. Penjumlahan dua matriks (A + B)
# 2. Perkalian dua matriks (A x B)
# 3. Transpose matriks (Matriks A)
# 4. Keluar
# ========================================
# Masukkan pilihan (1-4): 4
#
# Terima kasih! Keluar dari program.
#
# Silakan pilih Kasus yang ingin dijalankan:
# 1. Kasus 1: Matriks A (2x2), Matriks B (2x2)
# 2. Kasus 2: Matriks A (2x3), Matriks B (3x2)
# 3. Kasus 3: Matriks A (3x3), Matriks B (3x3)
# 4. Kasus 4: Matriks A (3x2), Matriks B (3x2)
# 5. Keluar Program Utama
# Masukkan nomor Kasus (1-5): 3
#
# ======== Kasus 3 Dijalankan ========
# Ukuran Matriks: A(3x3) dan B(3x3)
#
# Masukkan elemen matriks A (3x3):
# Elemen [1,1]: 1
# Elemen [1,2]: 2
# Elemen [1,3]: 3
# Elemen [2,1]: 4
# Elemen [2,2]: 5
# Elemen [2,3]: 6
# Elemen [3,1]: 7
# Elemen [3,2]: 8
# Elemen [3,3]: 9
#
# Masukkan elemen matriks B (3x3):
# Elemen [1,1]: 10
# Elemen [1,2]: 11
# Elemen [1,3]: 12
# Elemen [2,1]: 13
# Elemen [2,2]: 14
# Elemen [2,3]: 15
# Elemen [3,1]: 16
# Elemen [3,2]: 17
# Elemen [3,3]: 18
#
# ========================================
# Pilihan Operasi untuk Matriks A (3x3) dan B (3x3)
# 1. Penjumlahan dua matriks (A + B)
# 2. Perkalian dua matriks (A x B)
# 3. Transpose matriks (Matriks A)
# 4. Keluar
# ========================================
# Masukkan pilihan (1-4): 1
#
# --- Hasil Penjumlahan Matriks A + B ---
# 11.00	13.00	15.00
# 17.00	19.00	21.00
# 23.00	25.00	27.00
#
# ========================================
# Pilihan Operasi untuk Matriks A (3x3) dan B (3x3)
# 1. Penjumlahan dua matriks (A + B)
# 2. Perkalian dua matriks (A x B)
# 3. Transpose matriks (Matriks A)
# 4. Keluar
# ========================================
# Masukkan pilihan (1-4): 2
#
# --- Hasil Perkalian Matriks A x B ---
# 84.00	90.00	96.00
# 201.00	216.00	231.00
# 318.00	342.00	366.00
#
# ========================================
# Pilihan Operasi untuk Matriks A (3x3) dan B (3x3)
# 1. Penjumlahan dua matriks (A + B)
# 2. Perkalian dua matriks (A x B)
# 3. Transpose matriks (Matriks A)
# 4. Keluar
# ========================================
# Masukkan pilihan (1-4): 3
#
# --- Hasil Transpose Matriks A ---
# 1.00	4.00	7.00
# 2.00	5.00	8.00
# 3.00	6.00	9.00
#
# ========================================
# Pilihan Operasi untuk Matriks A (3x3) dan B (3x3)
# 1. Penjumlahan dua matriks (A + B)
# 2. Perkalian dua matriks (A x B)
# 3. Transpose matriks (Matriks A)
# 4. Keluar
# ========================================
# Masukkan pilihan (1-4): 4
#
# Terima kasih! Keluar dari program.
#
# Silakan pilih Kasus yang ingin dijalankan:
# 1. Kasus 1: Matriks A (2x2), Matriks B (2x2)
# 2. Kasus 2: Matriks A (2x3), Matriks B (3x2)
# 3. Kasus 3: Matriks A (3x3), Matriks B (3x3)
# 4. Kasus 4: Matriks A (3x2), Matriks B (3x2)
# 5. Keluar Program Utama
# Masukkan nomor Kasus (1-5): 4
#
# ======== Kasus 4 Dijalankan ========
# Ukuran Matriks: A(3x2) dan B(3x2)
#
# Masukkan elemen matriks A (3x2):
# Elemen [1,1]: 1
# Elemen [1,2]: 2
# Elemen [2,1]: 3
# Elemen [2,2]: 4
# Elemen [3,1]: 5
# Elemen [3,2]: 6
#
# Masukkan elemen matriks B (3x2):
# Elemen [1,1]: 7
# Elemen [1,2]: 8
# Elemen [2,1]: 9
# Elemen [2,2]: 10
# Elemen [3,1]: 11
# Elemen [3,2]: 12
#
# ========================================
# Pilihan Operasi untuk Matriks A (3x2) dan B (3x2)
# 1. Penjumlahan dua matriks (A + B)
# 2. Perkalian dua matriks (A x B)
# 3. Transpose matriks (Matriks A)
# 4. Keluar
# ========================================
# Masukkan pilihan (1-4): 1
#
# --- Hasil Penjumlahan Matriks A + B ---
# 8.00	10.00
# 12.00	14.00
# 16.00	18.00
#
# ========================================
# Pilihan Operasi untuk Matriks A (3x2) dan B (3x2)
# 1. Penjumlahan dua matriks (A + B)
# 2. Perkalian dua matriks (A x B)
# 3. Transpose matriks (Matriks A)
# 4. Keluar
# ========================================
# Masukkan pilihan (1-4): 2
#
# --- Perkalian Gagal ---
# Perkalian matriks hanya bisa dilakukan jika jumlah kolom matriks pertama (A) sama dengan jumlah baris matriks kedua (B).
# Ukuran A: 3x2, Ukuran B: 3x2
#
# ========================================
# Pilihan Operasi untuk Matriks A (3x2) dan B (3x2)
# 1. Penjumlahan dua matriks (A + B)
# 2. Perkalian dua matriks (A x B)
# 3. Transpose matriks (Matriks A)
# 4. Keluar
# ========================================
# Masukkan pilihan (1-4): 3
#
# --- Hasil Transpose Matriks A ---
# 1.00	3.00	5.00
# 2.00	4.00	6.00
#
# ========================================
# Pilihan Operasi untuk Matriks A (3x2) dan B (3x2)
# 1. Penjumlahan dua matriks (A + B)
# 2. Perkalian dua matriks (A x B)
# 3. Transpose matriks (Matriks A)
# 4. Keluar
# ========================================
# Masukkan pilihan (1-4): 4
#
# Terima kasih! Keluar dari program.
#
# Silakan pilih Kasus yang ingin dijalankan:
# 1. Kasus 1: Matriks A (2x2), Matriks B (2x2)
# 2. Kasus 2: Matriks A (2x3), Matriks B (3x2)
# 3. Kasus 3: Matriks A (3x3), Matriks B (3x3)
# 4. Kasus 4: Matriks A (3x2), Matriks B (3x2)
# 5. Keluar Program Utama
# Masukkan nomor Kasus (1-5): 5
# Keluar dari program utama.
